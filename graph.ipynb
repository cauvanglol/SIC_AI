# %%
import matplotlib.pyplot as plt
import numpy as np
"""
# %matplotlib inline

x = np.array(['Q1', 'Q2', 'Q3', 'Q4'])  # tao truc x
y = np.array([234, 345.5, 300, 199])  # tao truc y

plt.bar(x, y, color='yellow')  # tao bieu do
plt.title('BAR CHART')  # chen tieu de
plt.show()
"""
x=np.random.randn(10000)
plt.hist(x,bins=100,color='blue',density=False)
plt.title('HISTOGRSM')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y.np.sin(x)
plt.plot(x,y,color='red',maker='o',linstytle='none',makersize=5,alphe
